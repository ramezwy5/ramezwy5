# %%
import sys
sys.getdefaultencoding()

# %matplotlib inline
import pandas as pd

from IPython.core.display import HTML
css = open('./pycon-pandas-tutorial-1.0/style-table.css').read() + open('./pycon-pandas-tutorial-1.0/style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
uber = pd.read_csv('./Sept/w_8_13/date2_09_08_2017.csv', index_col=None)

# %%
type(uber['Total'])
# Out:
# pandas.core.series.Series

# %%
# uber.style.set_properties(**{'border': '1.3px solid green', 'color': 'blue'})

# %%
def numeric_serrise(df, column):
    for i in range(len(df)):
            if type(df[column][i]) == float:
                continue
            else:
                df[column][i] = df[column][i].replace("$", "")
    df[column]=pd.to_numeric(df[column])
    # df[column] = df[column].astype(float)
    total = round(df[column].sum(), 2)
    return df[column], total

# %%
numeric_serrise(uber, 'Refunds Toll')
# Out:
# <ipython-input-126-e6fc4a30ef27>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = df[column][i].replace("$", "")
# (0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#  5       NaN
#  6       NaN
#  7       NaN
#  8      2.45
#  9       NaN
#  10     1.35
#  11     2.45
#  12      NaN
#  13      NaN
#  14     3.00
#  15    21.45
#  16      NaN
#  17      NaN
#  18      NaN
#  19      NaN
#  20      NaN
#  21     2.45
#  Name: Refunds Toll, dtype: float64,
#  33.15)

# %%
numeric_serrise(uber, 'Total')
# Out:
# <ipython-input-126-e6fc4a30ef27>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = df[column][i].replace("$", "")
# (0     14.29
#  1     17.46
#  2      3.90
#  3      3.94
#  4      7.21
#  5      8.79
#  6      3.93
#  7      3.90
#  8     20.18
#  9      3.88
#  10    11.53
#  11    18.31
#  12     3.97
#  13     3.93
#  14    18.12
#  15    50.54
#  16     4.27
#  17     6.60
#  18     3.92
#  19    17.27
#  20     4.38
#  21    19.28
#  Name: Total, dtype: float64,
#  249.6)

# %%
uber.sort_values('Date/Time')
# Out:
#       Driver Name  Phone Number                    Email  \
# 3   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 20  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 11  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 0   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 12  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 17  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 6   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 15  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 19  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 21  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 5   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 1   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 16  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 9   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 10  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# ...

# %%
uber = uber.loc[~uber['Type'].str.contains("uberXL")]

# %%
uber.to_csv('uberx.csv', index=False, sep=';')

# %%
uber
# Out:
#       Driver Name  Phone Number                    Email  \
# 0   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 1   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 2   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 3   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 4   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 5   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 6   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 7   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 8   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 9   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 10  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 11  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 12  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 13  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 14  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# ...

# %%
uber.loc[pd.to_datetime(uber['Date/Time']).sort_values().index]
# Out:
#       Driver Name  Phone Number                    Email  \
# 3   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 20  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 11  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 0   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 12  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 17  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 6   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 15  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 16  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 9   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 10  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 13  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 4   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 14  Ramez Youssef           NaN  ramezwyoussef@gmail.com
# 2   Ramez Youssef           NaN  ramezwyoussef@gmail.com
# ...
